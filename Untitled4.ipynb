# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\Mritunjoy Paul\CSV files\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Clean TotalCharges
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df.dropna(subset=['TotalCharges'], inplace=True)

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %%
# Drop ID, encode target
df.drop("customerID", axis=1, inplace=True)
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
# One-hot encode categorical columns
df = pd.get_dummies(df, drop_first=True)

# %%
# Split features/target
X = df.drop('Churn', axis=1)
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

# %%
for name, model in models.items():
    print(f"🔷 Model: {name}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("ROC-AUC:", roc_auc_score(y_test, y_proba))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("\n" + "-"*50 + "\n")
# Out:
# 🔷 Model: Logistic Regression
# Accuracy: 0.8002842928216063
# ROC-AUC: 0.8366382635074624
# Confusion Matrix:
#  [[913 120]
#  [161 213]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      1033
#            1       0.64      0.57      0.60       374
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.73      0.73      1407
# weighted avg       0.79      0.80      0.80      1407
#
#
# --------------------------------------------------
#
# 🔷 Model: Random Forest
# Accuracy: 0.7896233120113717
# ROC-AUC: 0.8164903116927489
# Confusion Matrix:
#  [[917 116]
#  [180 194]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1033
#            1       0.63      0.52      0.57       374
#
#     accuracy                           0.79      1407
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Use best model (example: Random Forest)
importances = models['Random Forest'].feature_importances_
feat_importance = pd.Series(importances, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=feat_importance[:10], y=feat_importance.index[:10])
plt.title("Top 10 Feature Importances (Random Forest)")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages("Churn_Analysis_Report.pdf") as pdf:
    plt.figure(figsize=(10, 6))
    sns.barplot(x=feat_importance[:10], y=feat_importance.index[:10])
    plt.title("Top 10 Feature Importances")
    plt.tight_layout()
    pdf.savefig()
    plt.close()

    # Add more charts similarly and save
    print("📄 PDF Report saved as 'Churn_Analysis_Report.pdf'")
# Out:
# 📄 PDF Report saved as 'Churn_Analysis_Report.pdf'

# %%
# Save this as `app.py` and run using: streamlit run app.py

import streamlit as st
import pandas as pd
import pickle

st.title("📊 Churn Prediction System")

uploaded_file = st.file_uploader("Upload Customer CSV", type=["csv"])
if uploaded_file:
    input_data = pd.read_csv(uploaded_file)
    model = pickle.load(open("rf_model.pkl", "rb"))  # Save earlier with joblib/pickle

    input_encoded = pd.get_dummies(input_data)
    missing_cols = set(X.columns) - set(input_encoded.columns)
    for col in missing_cols:
        input_encoded[col] = 0
    input_encoded = input_encoded[X.columns]

    predictions = model.predict_proba(input_encoded)[:, 1]
    input_data['Churn Probability'] = predictions
    st.write(input_data[['Churn Probability']])
# Out:
# 2025-07-31 16:05:47.170
# ...
#   command:
#
#     streamlit run C:\Users\Mritunjoy Paul\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
